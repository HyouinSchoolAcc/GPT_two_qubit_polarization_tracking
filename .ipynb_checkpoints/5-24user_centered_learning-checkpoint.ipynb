# %%
#import some stuff
import pandas as pd
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import torch
import torch.nn as nn
import random
import math
from scipy.optimize import minimize
from scipy.interpolate import CubicSpline
import ipywidgets as widgets
from IPython.display import display
import torch
import torch.nn as nn
import torch.optim as optim
import gc

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
def clean_memory():
    gc.collect()           # Garbage collect Python objects
    torch.cuda.empty_cache()  # Clear cached memory on GPU


data_dir = "C:/Users/yueze/Desktop/GPT_two_qubit_polarization_tracking/20240506_2131.csv"
df = pd.read_csv(data_dir)
print(df.head)

features = ["AI0","AI1","AI2"]
targets  = ["AI3","AI4","AI5"]
x = df[features]  # Dropping original targets as we'll use aligned targets
y = df[targets]  # Using aligned targets
split_idx = int(len(df) * 0.9)
length_read=len(df)
# Split into training and testing sets
x_train = x.iloc[:split_idx]
y_train = y.iloc[:split_idx]
x_test = x.iloc[split_idx:]
y_test = y.iloc[split_idx:]

input_feature_dim = 3  # Each input element is a 1x3 vector
embed_size = 64
target_dim = 3
block_size = 40
num_heads = 16
max_iters = 144
batch_size = 10
eval_iters = 200
eval_interval = 1
num_layers=5

def get_batch3(split):
    # Select the correct data split
    if split == 'train':
        a, b, max_index = x_train, y_train, int(length_read * 0.9) - block_size - 1
    else:  # split == 'test'
        a, b, max_index = x_test, y_test, length_read - (int(length_read * 0.9) + block_size + 1)

    # Generate random indices for batch selection, ensuring they're within bounds
    ix = torch.randint(0, max_index, (batch_size,))

    # Initialize lists to hold the batches
    x_batch = []
    y_batch = []

    for i in ix:
        try:
                        # Extract the sequence from 'a' and the corresponding target from 'b'
            seq = torch.tensor(a.iloc[i.item():i.item() + block_size].astype(np.float32).values, dtype=torch.float32)
            target = torch.tensor(b.iloc[i.item() + block_size].astype(np.float32).values, dtype=torch.float32)

            x_batch.append(seq)
            y_batch.append(target)
        except IndexError as e:
            print(f"IndexError for index {i.item()}: {str(e)}")
            print(f"Attempting to access index [{i.item()}:{i.item() + block_size}] in 'a' with shape {a.shape}")
            print(f"Attempting to access index {i.item() + block_size} in 'b' with shape {b.shape}")
            # Optionally, break or continue depending on desired behavior on error
            break  # or continue

    if not x_batch or not y_batch:
        print("Error: Batch could not be created due to index issues.")
        return None, None

    # Stack the collected sequences and targets into tensors
    xstack = torch.stack(x_batch)
    ystack = torch.stack(y_batch)

    return xstack, ystack
class SelfAttention(nn.Module):
    def __init__(self, embed_size):
        super(SelfAttention, self).__init__()
        self.embed_size = embed_size

        self.keys = nn.Linear(embed_size, embed_size, bias=False)
        self.queries = nn.Linear(embed_size, embed_size, bias=False)
        self.values = nn.Linear(embed_size, embed_size, bias=False)

    def forward(self, x):
        K = self.keys(x)
        Q = self.queries(x)
        V = self.values(x)

        attention_scores = torch.matmul(Q, K.transpose(-2, -1)) / self.embed_size ** 0.5
        attention = torch.softmax(attention_scores, dim=-1)

        attended = torch.matmul(attention, V)
        return attended

class MultiHeadAttention(nn.Module):
    def __init__(self, embed_size, num_heads):
        super(MultiHeadAttention, self).__init__()
        self.embed_size = embed_size
        self.num_heads = num_heads

        assert embed_size % num_heads == 0

        self.head_dim = embed_size // num_heads

        self.keys = nn.Linear(embed_size, embed_size, bias=False)
        self.queries = nn.Linear(embed_size, embed_size, bias=False)
        self.values = nn.Linear(embed_size, embed_size, bias=False)

        self.fc_out = nn.Linear(embed_size, embed_size)

    def forward(self, x):
        batch_size, seq_length, _ = x.shape

        keys = self.keys(x).view(batch_size, seq_length, self.num_heads, self.head_dim)
        queries = self.queries(x).view(batch_size, seq_length, self.num_heads, self.head_dim)
        values = self.values(x).view(batch_size, seq_length, self.num_heads, self.head_dim)

        attention_scores = torch.einsum("bnqh,bnkh->bnqk", [queries, keys]) / (self.head_dim ** 0.5)
        attention = torch.softmax(attention_scores, dim=-1)

        attended = torch.einsum("bnqk,bnkv->bnqv", [attention, values]).reshape(batch_size, seq_length, self.embed_size)

        output = self.fc_out(attended)
        return output

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch3(split)
            X, Y = X.to(device), Y.to(device)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train
    del X, Y
    return out

class TransformerBlock(nn.Module):
    def __init__(self, embed_size, num_heads):
        super(TransformerBlock, self).__init__()
        self.norm1 = nn.LayerNorm(embed_size)
        self.attention = MultiHeadAttention(embed_size, num_heads)
        self.dropout1 = nn.Dropout(0.1)

        self.norm2 = nn.LayerNorm(embed_size)
        self.feed_forward = nn.Sequential(
            nn.Linear(embed_size, 2 * embed_size),
            nn.ReLU(),
            nn.Linear(2 * embed_size, embed_size),
        )
        self.dropout2 = nn.Dropout(0.1)

    def forward(self, value):
        x = self.norm1(value)
        attention_output = self.attention(x)
        x = value + self.dropout1(attention_output)  # Residual connection and dropout after attention
        x = self.norm2(x)
        feed_forward_output = self.feed_forward(x)
        out = value + self.dropout2(feed_forward_output)  # Residual connection and dropout after FFN
        return out

# Positional Encoding in Encoder class should be moved to the device
class Encoder(nn.Module):
    def __init__(self, input_feature_dim, embed_size, num_heads, num_layers, seq_length):
        super(Encoder, self).__init__()
        self.input_fc = nn.Linear(input_feature_dim, embed_size)
        self.positional_encoding = nn.Parameter(torch.randn(1, seq_length, embed_size)).to(device)
        self.layers = nn.ModuleList([
            TransformerBlock(embed_size, num_heads) for _ in range(num_layers)])
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.input_fc(x)) + self.positional_encoding
        for layer in self.layers:
            x = layer(x)
        return x

    def to_cpu(self):
        # Move the entire model to CPU
        self.input_fc.to('cpu')
        self.positional_encoding.data = self.positional_encoding.data.cpu()
        for layer in self.layers:
            layer.to('cpu')
        self.relu.to('cpu')
        torch.cuda.empty_cache()

class EncoderDecoderModelWithMultiHeadAttention(nn.Module):
    def __init__(self, input_feature_dim, embed_size, target_dim, seq_length, num_heads, num_layers):
        super(EncoderDecoderModelWithMultiHeadAttention, self).__init__()
        self.encoder = Encoder(input_feature_dim, embed_size, num_heads, num_layers, seq_length)
        self.decoder = nn.Sequential(
            nn.Linear(embed_size, target_dim),
        )

    def forward(self, x, targets):
        encoded = self.encoder(x)
        encoded_pooled = torch.mean(encoded, dim=1)
        decoded = self.decoder(encoded_pooled)

        if targets is not None:
            loss = criterion(decoded, targets)
            return decoded, loss


        return decoded, None

    def to_cpu(self):
        self.encoder.to_cpu()
        for layer in self.decoder:
            layer.to('cpu')
        torch.cuda.empty_cache()



actuals = []
predictions = []
if __name__ == "__main__":
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    model = EncoderDecoderModelWithMultiHeadAttention(input_feature_dim, embed_size, target_dim, block_size, num_heads, num_layers).to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss()

    for iter in range(max_iters):
        # Evaluate the loss periodically
        if iter % eval_interval == 0 or iter == max_iters - 1:
            losses = estimate_loss()
            print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

        xb, yb = get_batch3('train')
        xb, yb = xb.to(device), yb.to(device)  # Ensure these tensors are on the correct device

        predictions, loss = model(xb, yb)
        optimizer.zero_grad(set_to_none=True)
        loss.backward()
        optimizer.step()
                # After using tensors in a training step
        del xb, yb, predictions  # Assuming these are not needed after the training step
        clean_memory()  # Call this to clear memory
    print("Loss:", loss.item())
    del loss  # Assuming these are not needed after the training step
    clean_memory()  # Call this to clear memoryq
    model.to_cpu()
# Out:
# <bound method NDFrame.head of           TimeStamps       AI0       AI1       AI2       AI3       AI4  \
# 0           0.000000  2.229548  0.295483 -1.081807  1.623932 -1.120879
# 1           0.101122  2.219780  0.295483 -1.101343  1.633699 -1.101343
# 2           0.203640  2.210012  0.285714 -1.081807  1.643468 -1.081807
# 3           0.300221  2.219780  0.305250 -1.101343  1.653235 -1.072039
# 4           0.403315  2.200244  0.315019 -1.101343  1.653235 -1.062271
# ...              ...       ...       ...       ...       ...       ...
# 711710  71171.002492 -0.964591 -2.029304 -1.062271 -0.925519  0.686203
# 711711  71171.100106 -0.876678 -2.078144 -1.013431 -0.915751  0.676435
# 711712  71171.201757 -0.759462 -2.136752 -0.993895 -0.896214  0.637362
# 711713  71171.303305 -0.769231 -2.126984 -1.032967 -0.827839  0.656898
# 711714  71171.401576 -0.769231 -2.146520 -0.896214 -0.905983  0.520146
#
#              AI5
# 0      -1.492064
# 1      -1.501831
# 2      -1.501831
# 3      -1.492064
# 4      -1.492064
# ...          ...
# 711710 -2.185592
# 711711 -2.185592
# 711712 -2.214896
# 711713 -2.205128
# 711714 -2.214896
#
# [711715 rows x 7 columns]>
# step 0: train loss 2.9732, val loss 1.6575
# step 1: train loss 1.7643, val loss 1.5431
# step 2: train loss 1.1092, val loss 1.8609
# step 3: train loss 0.9610, val loss 2.6268
# step 4: train loss 1.1857, val loss 3.2984
# step 5: train loss 1.2120, val loss 3.0838
# step 6: train loss 1.0795, val loss 2.5728
# step 7: train loss 0.9030, val loss 1.8725
# step 8: train loss 0.6906, val loss 1.2540
# step 9: train loss 0.5729, val loss 0.8176
# step 10: train loss 0.5155, val loss 0.4596
# step 11: train loss 0.4731, val loss 0.2513
# step 12: train loss 0.4403, val loss 0.1233
# step 13: train loss 0.4172, val loss 0.0642
# step 14: train loss 0.3714, val loss 0.0685
# step 15: train loss 0.3446, val loss 0.1064
# step 16: train loss 0.3341, val loss 0.1673
# step 17: train loss 0.3315, val loss 0.2214
# step 18: train loss 0.3322, val loss 0.2727
# step 19: train loss 0.3387, val loss 0.3059
# step 20: train loss 0.3336, val loss 0.3452
# step 21: train loss 0.3168, val loss 0.3662
# step 22: train loss 0.2775, val loss 0.3917
# step 23: train loss 0.2591, val loss 0.3970
# step 24: train loss 0.2633, val loss 0.3916
# step 25: train loss 0.2732, val loss 0.3720
# step 26: train loss 0.2780, val loss 0.3288
# step 27: train loss 0.2687, val loss 0.2761
# step 28: train loss 0.2773, val loss 0.2317
# step 29: train loss 0.2672, val loss 0.1926
# step 30: train loss 0.2452, val loss 0.1694
# step 31: train loss 0.2413, val loss 0.1650
# step 32: train loss 0.2325, val loss 0.1737
# step 33: train loss 0.2334, val loss 0.1809
# step 34: train loss 0.2375, val loss 0.1890
# step 35: train loss 0.2196, val loss 0.1942
# step 36: train loss 0.2410, val loss 0.2066
# step 37: train loss 0.2304, val loss 0.2161
# step 38: train loss 0.2368, val loss 0.2126
# step 39: train loss 0.2353, val loss 0.1858
# step 40: train loss 0.2417, val loss 0.1654
# step 41: train loss 0.2226, val loss 0.1367
# step 42: train loss 0.1991, val loss 0.1072
# step 43: train loss 0.1993, val loss 0.0871
# step 44: train loss 0.1947, val loss 0.0704
# step 45: train loss 0.2014, val loss 0.0625
# step 46: train loss 0.2028, val loss 0.0552
# step 47: train loss 0.2013, val loss 0.0516
# step 48: train loss 0.2053, val loss 0.0536
# step 49: train loss 0.2115, val loss 0.0663
# step 50: train loss 0.2008, val loss 0.0842
# step 51: train loss 0.1877, val loss 0.1027
# step 52: train loss 0.1778, val loss 0.1177
# step 53: train loss 0.1781, val loss 0.1514
# step 54: train loss 0.1772, val loss 0.1997
# step 55: train loss 0.1876, val loss 0.2560
# step 56: train loss 0.2070, val loss 0.2875
# step 57: train loss 0.1970, val loss 0.2738
# step 58: train loss 0.1814, val loss 0.2249
# step 59: train loss 0.1665, val loss 0.1437
# step 60: train loss 0.1552, val loss 0.0844
# step 61: train loss 0.1568, val loss 0.0516
# step 62: train loss 0.1564, val loss 0.0421
# step 63: train loss 0.1652, val loss 0.0386
# step 64: train loss 0.1696, val loss 0.0399
# step 65: train loss 0.1764, val loss 0.0417
# step 66: train loss 0.1663, val loss 0.0406
# step 67: train loss 0.1588, val loss 0.0390
# step 68: train loss 0.1472, val loss 0.0351
# step 69: train loss 0.1356, val loss 0.0391
# step 70: train loss 0.1314, val loss 0.0478
# step 71: train loss 0.1412, val loss 0.0623
# step 72: train loss 0.1440, val loss 0.0713
# step 73: train loss 0.1476, val loss 0.0755
# step 74: train loss 0.1392, val loss 0.0671
# step 75: train loss 0.1356, val loss 0.0650
# step 76: train loss 0.1327, val loss 0.0568
# step 77: train loss 0.1300, val loss 0.0501
# step 78: train loss 0.1290, val loss 0.0458
# step 79: train loss 0.1351, val loss 0.0438
# step 80: train loss 0.1311, val loss 0.0434
# step 81: train loss 0.1301, val loss 0.0502
# step 82: train loss 0.1441, val loss 0.0576
# step 83: train loss 0.1362, val loss 0.0615
# step 84: train loss 0.1338, val loss 0.0569
# step 85: train loss 0.1426, val loss 0.0476
# step 86: train loss 0.1327, val loss 0.0381
# step 87: train loss 0.1258, val loss 0.0331
# step 88: train loss 0.1345, val loss 0.0396
# step 89: train loss 0.1346, val loss 0.0488
# step 90: train loss 0.1378, val loss 0.0638
# step 91: train loss 0.1308, val loss 0.0701
# step 92: train loss 0.1384, val loss 0.0802
# step 93: train loss 0.1436, val loss 0.0862
# step 94: train loss 0.1448, val loss 0.0793
# step 95: train loss 0.1459, val loss 0.0767
# step 96: train loss 0.1310, val loss 0.0631
# step 97: train loss 0.1239, val loss 0.0616
# step 98: train loss 0.1314, val loss 0.0724
# step 99: train loss 0.1331, val loss 0.0923
# step 100: train loss 0.1424, val loss 0.1098
# step 101: train loss 0.1319, val loss 0.1305
# step 102: train loss 0.1352, val loss 0.1394
# step 103: train loss 0.1251, val loss 0.1284
# step 104: train loss 0.1276, val loss 0.1191
# step 105: train loss 0.1246, val loss 0.0788
# step 106: train loss 0.1217, val loss 0.0539
# step 107: train loss 0.1314, val loss 0.0397
# step 108: train loss 0.1271, val loss 0.0322
# step 109: train loss 0.1344, val loss 0.0275
# step 110: train loss 0.1275, val loss 0.0269
# step 111: train loss 0.1211, val loss 0.0276
# step 112: train loss 0.1227, val loss 0.0291
# step 113: train loss 0.1278, val loss 0.0334
# step 114: train loss 0.1301, val loss 0.0359
# step 115: train loss 0.1349, val loss 0.0312
# step 116: train loss 0.1318, val loss 0.0332
# step 117: train loss 0.1270, val loss 0.0273
# step 118: train loss 0.1259, val loss 0.0266
# step 119: train loss 0.1249, val loss 0.0340
# step 120: train loss 0.1268, val loss 0.0412
# step 121: train loss 0.1380, val loss 0.0500
# step 122: train loss 0.1244, val loss 0.0596
# step 123: train loss 0.1278, val loss 0.0655
# step 124: train loss 0.1165, val loss 0.0601
# step 125: train loss 0.1147, val loss 0.0454
# step 126: train loss 0.1213, val loss 0.0387
# step 127: train loss 0.1183, val loss 0.0325
# step 128: train loss 0.1252, val loss 0.0360
# step 129: train loss 0.1216, val loss 0.0423
# step 130: train loss 0.1185, val loss 0.0437
# step 131: train loss 0.1169, val loss 0.0491
# step 132: train loss 0.1083, val loss 0.0511
# step 133: train loss 0.1169, val loss 0.0514
# step 134: train loss 0.1180, val loss 0.0505
# step 135: train loss 0.1116, val loss 0.0557
# step 136: train loss 0.1154, val loss 0.0547
# step 137: train loss 0.1300, val loss 0.0517
# step 138: train loss 0.1384, val loss 0.0486
# step 139: train loss 0.1265, val loss 0.0476
# step 140: train loss 0.1115, val loss 0.0457
# step 141: train loss 0.1130, val loss 0.0493
# step 142: train loss 0.1154, val loss 0.0626
# step 143: train loss 0.1223, val loss 0.0776
# Loss: 0.15597058832645416

# %%
plt.figure(figsize=(10, 6))
plt.plot(df["AI3"][480400:480800])
plt.title('Feature AI3')
plt.xlabel('Index')
plt.ylabel('Value')
plt.show()

# %%
#1.Find out what section of the data has human variations
#2.Train on those data
#3.Test the parameters around a bit to optimize the model
#4.Test the human variation data on the inherant data
#5.If result matches up, skip to step 9, else: fine tune parameter of original model, now with a weighted loss of the background data (the background data has too much significance as it stands and thus we need to reduce its weights in the model).
#6.Try the attention model on legacy dataset to see if the legacy dataset with more data improves performance
#7.We now deem that the models we have are insufficient. Hypothesis: current dataset lacks datapoint, legacy dataset lacks synchronization. Contact anirudth for better data.
#8.Throw the model that uses the current user-generated data to anirudth so he can see how well the data fits with new 2 day data.
#9.Write a report on the significance of the current best model, explaining what we're ultimately trying to accomplish, why its significant, and consice without too much technical detail (user manual) so that professors who have no background and no intuition about ML can realize the differences of this scheme

# %%
#step 1:
#10:70;450:675;466000:466150;480400:480800

# %%
#step2:
# Assuming df is your dataframe and it has the required columns
features = ["AI0", "AI1", "AI2"]
targets  = ["AI3", "AI4", "AI5"]

# Splicing indices
train_indices = list(range(10, 70)) + list(range(450, 675)) + list(range(466000, 466150)) + list(range(480400,480800))

# Create a mask for the training indices
mask = df.index.isin(train_indices)

# Select the rows for x_train and x_validation
x_train = df.iloc[mask][features]
y_train = df.iloc[mask][targets]

x_test = df.iloc[~mask][features]
y_test = df.iloc[~mask][targets]

# Output the lengths of the training and testing sets
print(f"Length of training set: {len(x_train)}")
print(f"Length of testing set: {len(x_test)}")
length_read=len(x_train)
# Out:
# Length of training set: 835
# Length of testing set: 710880

# %%
if __name__ == "__main__":
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    model = EncoderDecoderModelWithMultiHeadAttention(input_feature_dim, embed_size, target_dim, block_size, num_heads, num_layers).to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss()

    for iter in range(max_iters):
        # Evaluate the loss periodically
        if iter % eval_interval == 0 or iter == max_iters - 1:
            losses = estimate_loss()
            print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

        xb, yb = get_batch3('train')
        xb, yb = xb.to(device), yb.to(device)  # Ensure these tensors are on the correct device

        predictions, loss = model(xb, yb)
        optimizer.zero_grad(set_to_none=True)
        loss.backward()
        optimizer.step()
                # After using tensors in a training step
        del xb, yb, predictions  # Assuming these are not needed after the training step
        clean_memory()  # Call this to clear memory
    print("Loss:", loss.item())
    del loss  # Assuming these are not needed after the training step
    clean_memory()  # Call this to clear memoryq
    model.to_cpu()
# Out:
# step 0: train loss 2.3846, val loss 3.9632
# step 1: train loss 2.3161, val loss 4.0162
# step 2: train loss 2.4421, val loss 4.2790
# step 3: train loss 2.4809, val loss 4.0674
# step 4: train loss 2.4641, val loss 3.2235
# step 5: train loss 2.1913, val loss 2.3544
# step 6: train loss 2.0296, val loss 1.6208
# step 7: train loss 1.9136, val loss 1.0563
# step 8: train loss 1.8048, val loss 0.7054
# step 9: train loss 1.7705, val loss 0.5251
# step 10: train loss 1.7021, val loss 0.4857
# step 11: train loss 1.6490, val loss 0.4684
# step 12: train loss 1.6595, val loss 0.5424
# step 13: train loss 1.6364, val loss 0.5570
# step 14: train loss 1.6563, val loss 0.5757
# step 15: train loss 1.6397, val loss 0.5537
# step 16: train loss 1.5882, val loss 0.4886
# step 17: train loss 1.5373, val loss 0.4076
# step 18: train loss 1.5491, val loss 0.3422
# step 19: train loss 1.5138, val loss 0.2691
# step 20: train loss 1.4820, val loss 0.2305
# step 21: train loss 1.4866, val loss 0.1727
# step 22: train loss 1.4509, val loss 0.1340
# step 23: train loss 1.4771, val loss 0.1045
# step 24: train loss 1.4385, val loss 0.0859
# step 25: train loss 1.4692, val loss 0.0823
# step 26: train loss 1.4628, val loss 0.0822
# step 27: train loss 1.5025, val loss 0.0836
# step 28: train loss 1.5245, val loss 0.1031
# step 29: train loss 1.4805, val loss 0.1230
# step 30: train loss 1.4982, val loss 0.1357
# step 31: train loss 1.4536, val loss 0.1213
# step 32: train loss 1.4077, val loss 0.1338
# step 33: train loss 1.4772, val loss 0.1459
# step 34: train loss 1.4335, val loss 0.1092
# step 35: train loss 1.4598, val loss 0.0849
# step 36: train loss 1.4700, val loss 0.0749
# step 37: train loss 1.4730, val loss 0.0829
# step 38: train loss 1.4948, val loss 0.0648
# step 39: train loss 1.4644, val loss 0.0469
# step 40: train loss 1.4298, val loss 0.0433
# step 41: train loss 1.5116, val loss 0.0530
# step 42: train loss 1.4261, val loss 0.0701
# step 43: train loss 1.4486, val loss 0.1053
# step 44: train loss 1.4020, val loss 0.1617
# step 45: train loss 1.4337, val loss 0.2384
# step 46: train loss 1.4388, val loss 0.3191
# step 47: train loss 1.4694, val loss 0.4092
# step 48: train loss 1.5046, val loss 0.4794
# step 49: train loss 1.4587, val loss 0.5293
# step 50: train loss 1.4851, val loss 0.5663
# step 51: train loss 1.4875, val loss 0.5843
# step 52: train loss 1.4680, val loss 0.5259
# step 53: train loss 1.4676, val loss 0.4726
# step 54: train loss 1.4816, val loss 0.3926
# step 55: train loss 1.4686, val loss 0.3221
# step 56: train loss 1.4433, val loss 0.2656
# step 57: train loss 1.4634, val loss 0.2063
# step 58: train loss 1.4280, val loss 0.1669
# step 59: train loss 1.4028, val loss 0.1375
# step 60: train loss 1.4130, val loss 0.1223
# step 61: train loss 1.4254, val loss 0.1213
# step 62: train loss 1.4472, val loss 0.1128
# step 63: train loss 1.3966, val loss 0.1121
# step 64: train loss 1.4163, val loss 0.1175
# step 65: train loss 1.3763, val loss 0.1347
# step 66: train loss 1.4822, val loss 0.1612
# step 67: train loss 1.4149, val loss 0.2030
# step 68: train loss 1.5231, val loss 0.2693
# step 69: train loss 1.4773, val loss 0.3062
# step 70: train loss 1.4838, val loss 0.2787
# step 71: train loss 1.4287, val loss 0.2157
# step 72: train loss 1.4182, val loss 0.1084
# step 73: train loss 1.4287, val loss 0.0442
# step 74: train loss 1.4227, val loss 0.0272
# step 75: train loss 1.5378, val loss 0.0547
# step 76: train loss 1.5139, val loss 0.0825
# step 77: train loss 1.5065, val loss 0.0796
# step 78: train loss 1.4886, val loss 0.0645
# step 79: train loss 1.4343, val loss 0.0515
# step 80: train loss 1.4632, val loss 0.0413
# step 81: train loss 1.4704, val loss 0.0300
# step 82: train loss 1.5193, val loss 0.0241
# step 83: train loss 1.5544, val loss 0.0196
# step 84: train loss 1.5354, val loss 0.0091
# step 85: train loss 1.5288, val loss 0.0073
# step 86: train loss 1.4337, val loss 0.0280
# step 87: train loss 1.3876, val loss 0.0724
# step 88: train loss 1.3498, val loss 0.1237
# step 89: train loss 1.3821, val loss 0.1775
# step 90: train loss 1.4295, val loss 0.2211
# step 91: train loss 1.4381, val loss 0.2238
# step 92: train loss 1.3660, val loss 0.2258
# step 93: train loss 1.4386, val loss 0.2504
# step 94: train loss 1.4444, val loss 0.2947
# step 95: train loss 1.4261, val loss 0.3036
# step 96: train loss 1.4135, val loss 0.3130
# step 97: train loss 1.4204, val loss 0.3285
# step 98: train loss 1.4081, val loss 0.3346
# step 99: train loss 1.4152, val loss 0.3354
# step 100: train loss 1.4149, val loss 0.3382
# step 101: train loss 1.3818, val loss 0.3298
# step 102: train loss 1.4169, val loss 0.2823
# step 103: train loss 1.3910, val loss 0.2319
# step 104: train loss 1.4148, val loss 0.1900
# step 105: train loss 1.4379, val loss 0.1546
# step 106: train loss 1.4157, val loss 0.1504
# step 107: train loss 1.4123, val loss 0.1486
# step 108: train loss 1.3960, val loss 0.1415
# step 109: train loss 1.4356, val loss 0.1138
# step 110: train loss 1.4724, val loss 0.0913
# step 111: train loss 1.4624, val loss 0.0721
# step 112: train loss 1.4840, val loss 0.0792
# step 113: train loss 1.4285, val loss 0.0863
# step 114: train loss 1.4494, val loss 0.0764
# step 115: train loss 1.4786, val loss 0.0660
# step 116: train loss 1.4430, val loss 0.0476
# step 117: train loss 1.4144, val loss 0.0458
# step 118: train loss 1.3864, val loss 0.0466
# step 119: train loss 1.4668, val loss 0.0421
# step 120: train loss 1.3842, val loss 0.0467
# step 121: train loss 1.4550, val loss 0.0403
# step 122: train loss 1.4121, val loss 0.0299
# step 123: train loss 1.4012, val loss 0.0201
# step 124: train loss 1.4013, val loss 0.0158
# step 125: train loss 1.3617, val loss 0.0258
# step 126: train loss 1.3492, val loss 0.0412
# step 127: train loss 1.3791, val loss 0.0594
# step 128: train loss 1.3710, val loss 0.0755
# step 129: train loss 1.4104, val loss 0.0832
# step 130: train loss 1.4291, val loss 0.0867
# step 131: train loss 1.3992, val loss 0.0862
# step 132: train loss 1.4043, val loss 0.1032
# step 133: train loss 1.4296, val loss 0.1142
# step 134: train loss 1.4081, val loss 0.1099
# step 135: train loss 1.4144, val loss 0.1149
# step 136: train loss 1.3604, val loss 0.1123
# step 137: train loss 1.3985, val loss 0.0977
# step 138: train loss 1.4054, val loss 0.0750
# step 139: train loss 1.3675, val loss 0.0561
# step 140: train loss 1.3496, val loss 0.0410
# step 141: train loss 1.3640, val loss 0.0516
# step 142: train loss 1.3840, val loss 0.0774
# step 143: train loss 1.4582, val loss 0.1183
# Loss: 1.7628904581069946

# %%
def prepare_full_dataset(x, block_size):
    full_sequences = []
    for i in range(len(x) - block_size):
        seq = torch.tensor(x.iloc[i:i + block_size].astype(np.float32).values)
        full_sequences.append(seq)

    full_dataset = torch.stack(full_sequences)
    return full_dataset

# Prepare the full dataset and send it to the correct device
x_full = prepare_full_dataset(df[features], block_size)
batch_size = 1000
num_samples = x_full.size(0)  # Get the total number of samples
all_predictions = []

model.to_cpu()  # Ensure the model is on the CPU

with torch.no_grad():
    for start_idx in range(0, num_samples, batch_size):
        end_idx = min(start_idx + batch_size, num_samples)  # Calculate the end index of the batch
        batch_x = x_full[start_idx:end_idx]  # Extract the batch
        predictions_batch, _ = model(batch_x, None)  # Get predictions for the batch
        all_predictions.append(predictions_batch.cpu())  # Collect the predictions

# Concatenate all batch predictions into a single tensor
predictions_full = torch.cat(all_predictions, dim=0)
# Convert the first dimension of the predictions to a NumPy array for easier handling with matplotlib
AI3 = predictions_full[:, 0].numpy()
AI4 = predictions_full[:, 1].numpy()
AI5 = predictions_full[:, 2].numpy()

plt.figure(figsize=(10, 6))
plt.plot(AI4)
plt.title('predicted AI4')
plt.xlabel('Index')
plt.ylabel('Value')
plt.show()

# %%
#now we have trained a model on tdf_full = pd.read_csv("./20240229_2308.csv", header=None)
df_full = pd.read_csv("./data_2.csv", header=None)

# The maximum length of the dataset is the number of rows
max_length = df_full.shape[0]

# Print the maximum length
print(f"The maximum length of the dataset is: {max_length}")

# Now, you can use this information to set length_read appropriately
length_read = min(12546000, max_length)  # for example, to limit it to 100000 or the maximum length available

df_reduced = df_full.iloc[::10000, :]
# Proceed with loading the desired portion of the dataset
df = pd.read_csv("./20240229_2308.csv", header=None).iloc[1:length_read, :6]
df.columns = ["l1","l2","l3","r1","r2","r3"]
df.head()
targets = ["r1", "r2", "r3"]
max_length = df.shape[0]

# Print the maximum length
print(f"The maximum length of the dataset is: {max_length}")
x = df.drop(columns=targets)
y = df[targets]

def prepare_full_dataset(x, block_size):
    full_sequences = []
    for i in range(len(x) - block_size):
        seq = torch.tensor(x.iloc[i:i + block_size].astype(np.float32).values)
        full_sequences.append(seq)
    full_dataset = torch.stack(full_sequences)
    return full_dataset

# Prepare the full dataset and send it to the correct device
x_full = prepare_full_dataset(x, block_size)

batch_size = 1000
num_samples = x_full.size(0)  # Get the total number of samples
all_predictions = []

model.to_cpu()  # Ensure the model is on the CPU

with torch.no_grad():
    for start_idx in range(0, num_samples, batch_size):
        end_idx = min(start_idx + batch_size, num_samples)  # Calculate the end index of the batch
        batch_x = x_full[start_idx:end_idx]  # Extract the batch
        predictions_batch, _ = model(batch_x, None)  # Get predictions for the batch
        all_predictions.append(predictions_batch.cpu())  # Collect the predictions

# Concatenate all batch predictions into a single tensor
predictions_full = torch.cat(all_predictions, dim=0)
# Out:
# C:\Users\yueze\AppData\Local\Temp\ipykernel_6912\1830165733.py:2: DtypeWarning: Columns (0,1,2,3,4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_full = pd.read_csv("./data_2.csv", header=None)
# The maximum length of the dataset is: 1736737
# C:\Users\yueze\AppData\Local\Temp\ipykernel_6912\1830165733.py:15: DtypeWarning: Columns (0,1,2,3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./20240229_2308.csv", header=None).iloc[1:length_read, :6]
# The maximum length of the dataset is: 1736736

# %%
AI3 = predictions_full[:, 0].numpy()
AI4 = predictions_full[:, 1].numpy()
AI5 = predictions_full[:, 2].numpy()
plt.figure(figsize=(12, 8))
plt.plot(df['r1'].astype(np.float64).values, label="Ground Truth 1", marker='o', linestyle='-', markersize=5)
plt.plot(df['r2'].astype(np.float64).values, label="Ground Truth 2", marker='x', linestyle='-', markersize=5)
plt.plot(df['r3'].astype(np.float64).values, label="Ground Truth 3", marker='s', linestyle='-', markersize=5)
plt.plot(AI3, label="Predicted 1", marker='o', linestyle='--', markersize=5)
plt.plot(AI4, label="Predicted 2", marker='x', linestyle='--', markersize=5)
plt.plot(AI5, label="Predicted 3", marker='s', linestyle='--', markersize=5)

plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Ground Truth vs Predictions')
plt.legend(loc='best')
plt.grid(True)
plt.tight_layout()
plt.show()
